# %% [markdown]
# <a href="https://colab.research.google.com/github/learning710/11239A090_OpenCV_Lab/blob/main/Exercise7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()

import cv2
from google.colab.patches import cv2_imshow

img_path = next(iter(uploaded))

# read grayscale
img = cv2.imread(img_path, 0)

cv2_imshow(img)
# Out:
#      <input type="file" id="files-2f85f268-8ddf-400d-b7b2-6ab3de8a08b6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2f85f268-8ddf-400d-b7b2-6ab3de8a08b6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
sobelx = cv2.Sobel(img, cv2.CV_64F, 1, 0, ksize=5)
sobely = cv2.Sobel(img, cv2.CV_64F, 0, 1, ksize=5)

cv2_imshow(sobelx)
cv2_imshow(sobely)
# Out:
# <PIL.Image.Image image mode=L size=564x549>
# <PIL.Image.Image image mode=L size=564x549>

# %%
laplacian = cv2.Laplacian(img, cv2.CV_64F)

cv2_imshow(laplacian)
# Out:
# <PIL.Image.Image image mode=L size=564x549>

# %%
canny = cv2.Canny(img, 100, 200)

cv2_imshow(canny)
# Out:
# <PIL.Image.Image image mode=L size=564x549>
